# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('subdivisions/temporary_database.csv', index_col=0)
df['year'] = df['year'].apply(lambda date: datetime.datetime.strptime(date,"%Y-%m-%d"))
df
# Out:
#             year         city_code product_type  product  destinated_area
# 0     1974-01-01  960b4f2c94a2fb2c    temporary   Others              0.0
# 1     1974-01-01  746cc42bfb8f6b62    temporary   Others              0.0
# 2     1974-01-01  6cce2bf873870afc    temporary   Others              0.0
# 3     1974-01-01  4de42e351006a2ae    temporary   Others              0.0
# 4     1974-01-01  5b6072f8f6d37acc    temporary   Others              0.0
# ...          ...               ...          ...      ...              ...
# 43819 2017-01-01  64a227aa24370b17    temporary    Beans              7.0
# 43820 2017-01-01  64a227aa24370b17    temporary  Cassava            222.0
# 43821 2017-01-01  64a227aa24370b17    temporary     Corn           2100.0
# 43822 2017-01-01  64a227aa24370b17    temporary      Soy              NaN
# 43823 2017-01-01  64a227aa24370b17    temporary  Sorghum              NaN
#
# [43824 rows x 5 columns]

# %%
prod_names = df['product'].value_counts().index.to_list()
prod_list_by_name = {name: df[df['product'] == name].sort_values('destinated_area', ascending=False) for name in prod_names}
for name, prod in prod_list_by_name.items():
    y = prod['destinated_area']
    x = prod['year']
    fig = plt.figure(figsize=(6,6))
    ax = fig.add_subplot(111)
    ax.scatter(x, y, alpha=0.4, lw=0)
    ax.set_xlabel('Time')
    ax.set_ylabel('Area')
    ax.set_title(name)
    ax.grid(True)
